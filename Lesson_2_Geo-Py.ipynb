# %%
ice_cream_rating = 10
sleep_rating = 9

# %% [markdown]
# FirstName=input('What is your first name? ')
# LastName=input('What is your last name? ')

# %%
YourName = 'Your name is ', FirstName, LastName

# %%
print(YourName)
# Out:
# ('Your name is ', 'Robot', 'Winner')

# %%
import math
import statistics
happiness_rating =( ice_cream_rating + sleep_rating) / 2

# %%
print(happiness_rating)
# Out:
# 9.5

# %%
print('My name is', FirstName, LastName, 'and I am ',happiness_rating*10, '% happy!')
# Out:
# My name is Robot Winner and I am  95.0 % happy!
